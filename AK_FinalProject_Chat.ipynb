# %%
#!pip install --upgrade openai
#!pip install openai==0.28
#!pip install yfinance

# %%
import openai
import requests
import json
import sys

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import textblob
from textblob import TextBlob
import nltk
nltk.download('punkt')                        # nltk's sentence- and punctuation-handling routines
nltk.download('averaged_perceptron_tagger')   # nltk's part-of-speech-handling routines
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# True

# %%
def analyst_gpt(ticker='msft'):

    openai.api_key = 'sk-proj-HJJJAMqEOllZxBJJM7ljT3BlbkFJe6YYGFWlDbR5a5z9Cxh3'

    #input_text = "What are Wall Street analysts saying about" + ticker
    prompt = "I am looking for detailed analyst information about " + ticker + "Current analyst ratings (e.g., buy, hold, sell) and the overall consensus and Recent price targets set by analysts and the average price target."


    messages = [
    {"role": "system", "content": "You are a kind helpful assistant."},
    {"role": "user", "content": prompt}
    ]

    #chat = openai.chat.completions.create(model="gpt-3.5-turbo", messages=messages, max_tokens=500,temperature=0.5,)
    chat = openai.ChatCompletion.create(model="gpt-3.5-turbo", messages=messages, max_tokens=500,temperature=0.5,)


    reply = chat.choices[0].message.content
    return reply

# %%
analyst = TextBlob(analyst_gpt('msft'))
#print(analyst)
polarity = []
subjectivity = []
full_sentence = []
for sentence in analyst.sentences:
    full_sentence.append(sentence)
    polarity.append(sentence.sentiment.polarity)
    subjectivity.append(sentence.sentiment.subjectivity)
    #print (sentence, sentence.sentiment.subjectivity)
    #print(sentence, sentence.sentiment)

print(analyst.sentences)
# Creating a dictionary with columns and their corresponding values
data = {
    'Sentence': full_sentence,
    'Polarity': polarity,
    'Subjectivity': subjectivity
}

# Initializing the DataFrame
df = pd.DataFrame(data)
df
# Out:
# [Sentence("I can provide you with the information you're looking for."), Sentence("Here is the current analyst ratings for Microsoft Corporation (MSFT):
#
# - Buy: 29 analysts
# - Hold: 3 analysts
# - Sell: 0 analysts
#
# Overall Consensus: Strong Buy
#
# Recent Price Targets set by analysts:
# - Highest Price Target: $400
# - Lowest Price Target: $285
# - Average Price Target: $354.50
#
# Please note that these ratings and price targets are subject to change as analysts update their assessments of the company.")]
#                                             Sentence  Polarity  Subjectivity
# 0  (I,  , c, a, n,  , p, r, o, v, i, d, e,  , y, ...  0.000000      0.000000
# 1  (H, e, r, e,  , i, s,  , t, h, e,  , c, u, r, ...  0.088095      0.445238

# %%
import nltk
nltk.download('vader_lexicon')
from nltk.sentiment.vader import SentimentIntensityAnalyzer
# Out:
# [nltk_data] Downloading package vader_lexicon to /root/nltk_data...

# %%
def analyze_sentiment(text):
    # Initialize VADER sentiment analyzer
    sid = SentimentIntensityAnalyzer()

    # Get sentiment scores
    sentiment_scores = sid.polarity_scores(text)

    return sentiment_scores

# Example usage
#text = "Microsoft has been performing exceptionally well in the stock market recently!"
analyst = analyst_gpt('msft')
print(analyst)
sentiment = analyze_sentiment(analyst)
print(sentiment)
# Out:
# I can help you with that. Please note that analyst ratings and price targets can vary, so it's important to consider multiple sources for a well-rounded view. Here is some information about Microsoft Corporation (MSFT) based on recent data:
#
# Analyst Ratings:
# - Buy: 29 analysts
# - Hold: 4 analysts
# - Sell: 1 analyst
#
# Overall Consensus: Strong Buy
#
# Recent Price Targets:
# - The recent price targets set by analysts for MSFT range from $320 to $380 per share.
# - The average price target for MSFT is around $350 per share.
#
# Please keep in mind that these numbers are based on recent data and may change as new information becomes available. It's always a good idea to conduct your own research and consult with a financial advisor before making any investment decisions.
# {'neg': 0.0, 'neu': 0.847, 'pos': 0.153, 'compound': 0.9515}

# %%
def industry_gpt(ticker='msft'):

    openai.api_key = 'sk-proj-HJJJAMqEOllZxBJJM7ljT3BlbkFJe6YYGFWlDbR5a5z9Cxh3'

    #input_text = "What are Wall Street analysts saying about" + ticker
    # !prompt = "I am looking for detailed analyst information about " + ticker + "Current analyst ratings (e.g., buy, hold, sell) and the overall consensus and Recent price targets set by analysts and the average price target."
    prompt = "how is microsoft positioned to execute on the current trends in the tech industry in one paragraph"

    messages = [
    {"role": "system", "content": "You are a kind helpful assistant."},
    {"role": "user", "content": prompt}
    ]

    #chat = openai.chat.completions.create(model="gpt-3.5-turbo", messages=messages, max_tokens=500,temperature=0.5,)
    chat = openai.ChatCompletion.create(model="gpt-3.5-turbo", messages=messages, max_tokens=500,temperature=0.5,)


    reply = chat.choices[0].message.content
    return reply

# %%
industry = industry_gpt('msft')
print(industry)
sentiment = analyze_sentiment(industry)
print(sentiment)
# Out:
# /bin/bash: line 1: prompt: command not found
# Microsoft is well positioned to execute on the current trends in the tech industry due to its strong focus on cloud computing, artificial intelligence, and digital transformation. With its Azure cloud platform, Microsoft is a leader in providing scalable and secure cloud services to businesses of all sizes. The company's investments in AI research and development have enabled it to offer innovative solutions that leverage machine learning and natural language processing. Additionally, Microsoft's suite of productivity tools, such as Office 365 and Teams, are widely used for remote work and collaboration, aligning with the increasing demand for digital workplace solutions. Overall, Microsoft's diverse portfolio and commitment to innovation make it a key player in driving the ongoing technological advancements shaping the industry.
# {'neg': 0.011, 'neu': 0.805, 'pos': 0.184, 'compound': 0.9657}

# %%
def management_gpt(ticker='msft'):

    openai.api_key = 'sk-proj-HJJJAMqEOllZxBJJM7ljT3BlbkFJe6YYGFWlDbR5a5z9Cxh3'

    #input_text = "What are Wall Street analysts saying about" + ticker
    # !prompt = "I am looking for detailed analyst information about " + ticker + "Current analyst ratings (e.g., buy, hold, sell) and the overall consensus and Recent price targets set by analysts and the average price target."
    prompt = "Microsoft's management discussion and analysis document from the 2023 annual report"

    messages = [
    {"role": "system", "content": "You are a kind helpful assistant."},
    {"role": "user", "content": prompt}
    ]

    #chat = openai.chat.completions.create(model="gpt-3.5-turbo", messages=messages, max_tokens=500,temperature=0.5,)
    chat = openai.ChatCompletion.create(model="gpt-3.5-turbo", messages=messages, max_tokens=500,temperature=0.5,)


    reply = chat.choices[0].message.content
    return reply

# %%
mgmt = management_gpt('msft')
print(mgmt)
sentiment = analyze_sentiment(mgmt)
print(sentiment)
# Out:
# /bin/bash: line 1: prompt: command not found
# I'm sorry, but I am unable to provide verbatim excerpts from specific documents like the management discussion and analysis section of Microsoft's 2023 annual report as it is copyrighted material. However, I can provide you with a summary or general information about the company if that would be helpful to you. Let me know how I can assist you further.
# {'neg': 0.019, 'neu': 0.867, 'pos': 0.114, 'compound': 0.7783}

# %%
MDA_text = """Microsoft's Management Discussion and Analysis (MD&A) section from the 2023 annual report provides a comprehensive overview of its financial condition and results of operations for the fiscal year ended June 30, 2023. The key highlights include:
Financial Performance
* Revenue Growth: Microsoft reported strong revenue growth driven by its cloud computing services, particularly Azure, which saw significant demand from businesses undergoing digital transformation.
Operating Income: The company achieved a solid increase in operating income, reflecting efficient cost management and strong performance across its product lines.
Net Income: Microsoft’s net income increased substantially, underscored by high-margin cloud services and continued growth in Office Commercial and LinkedIn revenue.
Segment Analysis
Productivity and Business Processes: This segment, including Office Commercial, LinkedIn, and Dynamics, reported robust revenue growth due to increased customer adoption and subscription-based services.
Intelligent Cloud: Azure's revenue grew impressively, driven by strong demand for cloud-based solutions. The segment also benefited from increased sales of server products and cloud services.
More Personal Computing: This segment, which includes Windows, Surface, and gaming, experienced mixed results with growth in Windows Commercial and Surface devices but faced challenges in the consumer PC market.
Strategic Initiatives
AI and Innovation: Microsoft continued to invest heavily in AI across its products and services. Innovations in AI are integrated into products like Microsoft Teams, Outlook, and Bing, enhancing functionality and user experience.
Sustainability: The company reiterated its commitment to sustainability, aiming to be carbon negative by 2030. Investments in renewable energy and sustainable practices are central to Microsoft’s long-term strategy.
Cybersecurity: With the increasing threat landscape, Microsoft has expanded its cybersecurity offerings, focusing on protecting customers through advanced security solutions and services.
Outlook Looking ahead, Microsoft remains optimistic about its growth prospects, particularly in cloud computing and AI. The company plans to continue its strategic investments in these areas, along with a focus on expanding its footprint in emerging markets and new technology sectors.
For more detailed information, you can refer to the full MD&A section in Microsoft's 2023 Annual Report? (SEC.gov)?? (Microsoft Cloud)?.
"""

# %%
# !pip install transformers

# %%
from transformers import pipeline

# Initialize the summarizer pipeline
summarizer = pipeline("summarization")

# Summarize the text
summary = summarizer(MDA_text, max_length=150, min_length=50, do_sample=False)
print(summary[0]['summary_text'])
# Out:
# No model was supplied, defaulted to sshleifer/distilbart-cnn-12-6 and revision a4f8f3e (https://huggingface.co/sshleifer/distilbart-cnn-12-6).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:89: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# config.json:   0%|          | 0.00/1.80k [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/1.22G [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/26.0 [00:00<?, ?B/s]
# ...
